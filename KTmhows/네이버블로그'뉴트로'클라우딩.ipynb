# %%
from konlpy.tag import Twitter 
from collections import Counter

# %%
import openpyxl
workbook = openpyxl.load_workbook('C:/Users/CPBUserN/Desktop/KTmhows/네이버블로그크롤링_뉴트로_1901010~201020.xlsx')
worksheet = workbook['Sheet1']

# %%
list_var = []
cell_range=worksheet['A2':'A769']

for row in cell_range:
    for cell in row:
        list_var.append(cell.value)

# %%
twitter = Twitter() 
morphs = []
for sentence in list_var: 
    morphs.append(twitter.pos(sentence))
# Out:
# C:\BigData\anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
noun_adj_adv_list=[] 

for sentence in morphs : 
    for word, tag in sentence : 
        if tag in ['Noun']and ("느낌" not in word)and ("볼" not in word)and ("감" not in word)and ("안" not in word)and ("다시" not in word)and ("정도" not in word)and ("좀" not in word)and ("듯" not in word)and ("해" not in word)and ("개" not in word)and ("의" not in word)and ("또" not in word)and ("가지" not in word)and ("거" not in word)and ("분" not in word)and ("전" not in word)and ("요즘" not in word)and ("시간" not in word)and ("요" not in word)and ("저" not in word)and ("그" not in word)and ("곳" not in word)and ("더" not in word)and ("뉴트" not in word)and ("남성" not in word)and ("여성" not in word)and ("올해" not in word)and ("신한은행" not in word) and ("한국" not in word)and ("코리아" not in word)and ("반영" not in word)and ("고객" not in word)and ("롯데" not in word)and ("보기" not in word)and ("번가" not in word)and ("최근" not in word)and ("중" not in word)and ("전체" not in word)and ("관련" not in word)and ("트렌드" not in word)and ("세대" not in word)and ("제" not in word) and ("명" not in word)and ("것" not in word)and ("점" not in word)and ("로" not in word)and ("건" not in word) and ("후" not in word)and ("이" not in word)and ("위" not in word) and ("층" not in word)  and ("등" not in word)  and ("를" not in word) and ("배" not in word)and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word)and ("때" not in word)and ("진짜" not in word): 
            noun_adj_adv_list.append(word)

# %%
count = Counter(noun_adj_adv_list)
words = dict(count.most_common())
words
# Out:
# {'컬러': 1062,
#  '디자인': 924,
#  '사용': 787,
#  '공간': 733,
#  '카페': 655,
#  '패션': 614,
#  '생각': 610,
#  '사진': 607,
#  '인테리어': 598,
#  '스타일': 554,
#  '맛': 518,
#  '추억': 487,
#  '복고': 484,
#  '집': 447,
#  '브랜드': 445,
#  '사람': 429,
#  '오늘': 398,
#  '유행': 386,
#  '지금': 380,
#  '인기': 357,
#  '우리': 351,
#  '모습': 346,
#  '맥주': 343,
#  '출시': 341,
#  '문화': 309,
#  '가장': 304,
#  '다른': 303,
#  '옛날': 303,
#  '커피': 303,
#  '시작': 301,
#  '주문': 299,
#  '소품': 298,
#  '매력': 297,
#  '활용': 294,
#  '매트': 277,
#  '마음': 276,
#  '여기': 271,
#  '추천': 264,
#  '포인트': 261,
#  '조금': 261,
#  '번': 260,
#  '역시': 260,
#  '도': 257,
#  '여행': 256,
#  '내': 254,
#  '가격': 253,
#  '날': 252,
#  '눈': 250,
#  '서울': 245,
#  '모두': 242,
#  '자리': 241,
#  '재': 239,
#  '속': 238,
#  '메뉴': 236,
#  '한번': 234,
#  '걸': 234,
#  '틴트': 234,
#  '착용': 233,
#  '빈티': 232,
#  '앞': 230,
#  '처음': 226,
#  '보고': 224,
#  '음악': 222,
#  '선글라스': 221,
#  '연출': 219,
#  '여름': 219,
#  '알': 211,
#  '현대': 209,
#  '구매': 208,
#  '사실': 207,
#  '친구': 204,
# ...

# %%
from wordcloud import WordCloud 

import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
# %matplotlib inline

import matplotlib
from IPython.display import set_matplotlib_formats
matplotlib.rc('font',family = 'Malgun Gothic')

set_matplotlib_formats('retina')

matplotlib.rc('axes',unicode_minus = False)

# %%
from matplotlib import font_manager, rc
font_fname ="C:/Windows/Fonts/H2GTRE.TTF"    # A font of your choice
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)

# %%
from matplotlib.colors import LinearSegmentedColormap
colors = ["#c71f2e", "#11584a", "#FF8B8B", "#384883", "#f8a39e", "#d7942c"]
cmap = LinearSegmentedColormap.from_list("mycmap", colors)
wordcloud = WordCloud(font_path = font_fname, background_color='white',colormap = cmap, width=1500, height=1000,  stopwords=stopwords).generate_from_frequencies(words) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()
