# %% [markdown]
# ### 데이터분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
kt = pd.read_excel('C:/Users/CPBUserN/Desktop/KT엠하우스/PMS1234_2019_B2C_데이터.xlsx')

# %%
kt2 = pd.read_excel('C:/Users/CPBUserN/Desktop/KT엠하우스/회원matching.xlsx')

# %%
print(type(kt))
print(type(kt2))
print(type(ktl2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
ktl2 = pd.read_excel('C:/Users/CPBUserN/Desktop/KT엠하우스/라벨링 매칭 데이터.xlsx')

# %%
ktl2_0 = ktl2[ktl2['Label'].isin(['0'])]
ktl2_00 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_0.count()
# Out:
# 고객사명     89967
# 발신자번호    89967
# 수신자번호    89967
# 브랜드명     89967
# 상품명      89967
# 단가       89967
# 메세지내용    89967
# 발송일시     89967
# 교환일시     68790
# 생년       89967
# 성별       89928
# Label    89967
# dtype: int64

# %%
ktl2_1 = ktl2[ktl2['Label'].isin(['1'])]
ktl2_11 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_11.count()
# Out:
# 고객사명     12397
# 발신자번호    12397
# 수신자번호    12397
# 브랜드명     12397
# 상품명      12397
# 단가       12397
# 메세지내용    12397
# 발송일시     12397
# 교환일시      7827
# 생년       12397
# 성별       12397
# Label    12397
# dtype: int64

# %%
ktl2_2 = ktl2[ktl2['Label'].isin(['2'])]
ktl2_22 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_22.count()
# Out:
# 고객사명     12397
# 발신자번호    12397
# 수신자번호    12397
# 브랜드명     12397
# 상품명      12397
# 단가       12397
# 메세지내용    12397
# 발송일시     12397
# 교환일시      7827
# 생년       12397
# 성별       12397
# Label    12397
# dtype: int64

# %%
ktl2_3 = ktl2[ktl2['Label'].isin(['3'])]
ktl2_33 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_33.count()
# Out:
# 고객사명     12397
# 발신자번호    12397
# 수신자번호    12397
# 브랜드명     12397
# 상품명      12397
# 단가       12397
# 메세지내용    12397
# 발송일시     12397
# 교환일시      7827
# 생년       12397
# 성별       12397
# Label    12397
# dtype: int64

# %%
ktl2_4 = ktl2[ktl2['Label'].isin(['4'])]
ktl2_44 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_44.count()
# Out:
# 고객사명     12397
# 발신자번호    12397
# 수신자번호    12397
# 브랜드명     12397
# 상품명      12397
# 단가       12397
# 메세지내용    12397
# 발송일시     12397
# 교환일시      7827
# 생년       12397
# 성별       12397
# Label    12397
# dtype: int64

# %%
ktl2_5 = ktl2[ktl2['Label'].isin(['5'])]
ktl2_55 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_55.count()
# Out:
# 고객사명     12397
# 발신자번호    12397
# 수신자번호    12397
# 브랜드명     12397
# 상품명      12397
# 단가       12397
# 메세지내용    12397
# 발송일시     12397
# 교환일시      7827
# 생년       12397
# 성별       12397
# Label    12397
# dtype: int64

# %%
ktl2_6 = ktl2[ktl2['Label'].isin(['6'])]
ktl2_66 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_66.count()
# Out:
# 고객사명     12397
# 발신자번호    12397
# 수신자번호    12397
# 브랜드명     12397
# 상품명      12397
# 단가       12397
# 메세지내용    12397
# 발송일시     12397
# 교환일시      7827
# 생년       12397
# 성별       12397
# Label    12397
# dtype: int64

# %%
ktl2_7 = ktl2[ktl2['Label'].isin(['7'])]
ktl2_77 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_77.count()
# Out:
# 고객사명     12397
# 발신자번호    12397
# 수신자번호    12397
# 브랜드명     12397
# 상품명      12397
# 단가       12397
# 메세지내용    12397
# 발송일시     12397
# 교환일시      7827
# 생년       12397
# 성별       12397
# Label    12397
# dtype: int64

# %%
ktl2_8 = ktl2[ktl2['Label'].isin(['8'])]
ktl2_88 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_88.count()
# Out:
# 고객사명     12397
# 발신자번호    12397
# 수신자번호    12397
# 브랜드명     12397
# 상품명      12397
# 단가       12397
# 메세지내용    12397
# 발송일시     12397
# 교환일시      7827
# 생년       12397
# 성별       12397
# Label    12397
# dtype: int64

# %%
ktl2_9 = ktl2[ktl2['Label'].isin(['9'])]
ktl2_99 = ktl2[ktl2['생년'].isin(['2001','2002','2003','2004','2005','2006'])]
ktl2_99.count()
# Out:
# 고객사명     12397
# 발신자번호    12397
# 수신자번호    12397
# 브랜드명     12397
# 상품명      12397
# 단가       12397
# 메세지내용    12397
# 발송일시     12397
# 교환일시      7827
# 생년       12397
# 성별       12397
# Label    12397
# dtype: int64

# %%
ktl2_0 = ktl2[ktl2['Label'].isin(['0'])]
ktl2_00 = ktl2[ktl2['생년'].isin(['1991','1992','1993','1994','1995','1996','1997','1998','1999','2000'])]
ktl2_00.count()
# Out:
# 고객사명     31284
# 발신자번호    31284
# 수신자번호    31284
# 브랜드명     31284
# 상품명      31284
# 단가       31284
# 메세지내용    31284
# 발송일시     31284
# 교환일시     23728
# 생년       31284
# 성별       31284
# Label    31284
# dtype: int64

# %%
ktl2_1 = ktl2[ktl2['Label'].isin(['1'])]
ktl2_11 = ktl2[ktl2['생년'].isin(['1991','1992','1993','1994','1995','1996','1997','1998','1999','2000'])]
ktl2_11.count()
# Out:
# 고객사명     31284
# 발신자번호    31284
# 수신자번호    31284
# 브랜드명     31284
# 상품명      31284
# 단가       31284
# 메세지내용    31284
# 발송일시     31284
# 교환일시     23728
# 생년       31284
# 성별       31284
# Label    31284
# dtype: int64

# %%
ktl2_2 = ktl2[ktl2['Label'].isin(['2'])]

# %%
ktl2_22 = ktl2[ktl2['생년'].isin(['1991','1992','1993','1994','1995','1996','1997','1998','1999','2000'])]

# %%
ktl2_22.count()
# Out:
# 고객사명     31284
# 발신자번호    31284
# 수신자번호    31284
# 브랜드명     31284
# 상품명      31284
# 단가       31284
# 메세지내용    31284
# 발송일시     31284
# 교환일시     23728
# 생년       31284
# 성별       31284
# Label    31284
# dtype: int64

# %%
ktl2_3 = ktl2[ktl2['Label'].isin(['3'])]
ktl2_33 = ktl2[ktl2['생년'].isin(['1991','1992','1993','1994','1995','1996','1997','1998','1999','2000'])]

# %%
ktl2_33.count()
# Out:
# 고객사명     31284
# 발신자번호    31284
# 수신자번호    31284
# 브랜드명     31284
# 상품명      31284
# 단가       31284
# 메세지내용    31284
# 발송일시     31284
# 교환일시     23728
# 생년       31284
# 성별       31284
# Label    31284
# dtype: int64

# %%
ktl2_4 = ktl2[ktl2['Label'].isin(['4'])]
ktl2_44 = ktl2[ktl2['생년'].isin(['1991','1992','1993','1994','1995','1996','1997','1998','1999','2000'])]

# %%
ktl2_44.count()
# Out:
# 고객사명     31284
# 발신자번호    31284
# 수신자번호    31284
# 브랜드명     31284
# 상품명      31284
# 단가       31284
# 메세지내용    31284
# 발송일시     31284
# 교환일시     23728
# 생년       31284
# 성별       31284
# Label    31284
# dtype: int64

# %% [markdown]
# ## 인스타 크롤링 (30대취미)

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def insta_searching(word):
    url = "https://www.instagram.com/explore/tags/" + word
    return url

from selenium import webdriver
driver = webdriver.Chrome("C:/BigData/projects/chromedriver/chromedriver.exe")
import time

# %%
driver.get('https://www.instargram.com')
time.sleep(5) #시간을 넉넉히 설정합니다.

# %%
email = 'bsh2014@naver.com'   ### 사용할 계정 정보 입력
input_id = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[0]
input_id.clear()
input_id.send_keys(email)

# %%
password = 'rkddkwl0901!' ### 비번 정보 수정
input_pw = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[1]
input_pw.clear()
input_pw.send_keys(password)
input_pw.submit()

# %%
time.sleep(3)
word = "30대취미" #검색할 해시태그. 띄어쓰기를 사용하면 안됩니다
url = insta_searching(word)
driver.get(url)
time.sleep(2)

# %%
first = driver.find_element_by_css_selector("div._9AhH0")
first.click()
time.sleep(3)

# %%
#본문 내용, 작성 일시, 위치 정보 및 해시태그(#) 추출
import re 
def get_content(driver):
    # 1. 현재 페이지의 HTML 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')    
    # 2. 본문 내용 가져오기
    try:  			#여러 태그중 첫번째([0]) 태그를 선택  
        content = soup.select('div.C4VMK > span')[0].text 
        			#첫 게시글 본문 내용이 <div class="C4VMK"> 임을 알 수 있다.
                                #태그명이 div, class명이 C4VMK인 태그 아래에 있는 span 태그를 모두 선택.
    except:
        content = ' ' 
    # 3. 본문 내용에서 해시태그 가져오기(정규표현식 활용)
    tags = re.findall(r'#[^\s#,\\]+', content) # content 변수의 본문 내용 중 #으로 시작하며, #뒤에 연속된 문자(공백이나 #, \ 기호가 아닌 경우)를 모두 찾아 tags 변수에 저장
    # 4. 작성 일자 가져오기
    try:
        date = soup.select('time._1o9PC.Nzb55')[0]['datetime'][:10] #앞에서부터 10자리 글자
    except:
        date = ''
    # 5. 좋아요 수 가져오기
    try:
        like = soup.select('div.Nm9Fw > button')[0].text[4:-1] 
    except:
        like = 0
    # 6. 위치 정보 가져오기
    try:
        place = soup.select('div.JF9hh')[0].text
    except:
        place = ''
    data = [content, date, like, place, tags]
    return data

# %%
# 7. 수집한 정보 저장하기
def move_next(driver):
    right = driver.find_element_by_css_selector('a._65Bje.coreSpriteRightPaginationArrow') 
    right.click()
    time.sleep(3)

# %%
target = 1000 #크롤링할 게시물 수
for i in range(target):
    data = get_content(driver) #게시물 정보 가져오기
    results.append(data)
    move_next(driver)

# %%
print(results[:2])
# Out:
# [[' ', '', 0, '', []], ['오늘 착한 일해서 사례로 스벅이 티라미수 세트 겟또~😎#암쏘나이스 #암쏘쿨 #일상스타그램 #지갑 #주인찾아줌 #헤헤 #잘먹겠습니다 #스벅 #티라미수세트 #기프티쇼 #냠냠😋 #착한일 #일상스타그램', '2020-08-12', '17', '', ['#암쏘나이스', '#암쏘쿨', '#일상스타그램', '#지갑', '#주인찾아줌', '#헤헤', '#잘먹겠습니다', '#스벅', '#티라미수세트', '#기프티쇼', '#냠냠😋', '#착한일', '#일상스타그램']]]

# %%
import pandas as pd
results_df = pd.DataFrame(results)
results_df.to_excel('30대취미.xlsx', index=False)

# %% [markdown]
# ### 유튜브 크롤링 https://m.blog.naver.com/blueday9404/221867706722

# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver as wd

## CHECK START TIME
start = time.time()       # 시작 시간 (전체 수행시간을 구하기 위함)
driver = wd.Chrome(executable_path="C:/BigData/projects/chromedriver/chromedriver.exe")

# INPUT YOUTUBE URL
url = "https://www.youtube.com/watch?v=DN1GACKSuXQ"       # 댓글 수집할 Youtube URL입력
driver.get(url)

# %%
last_page_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(3.0)
    new_page_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    if new_page_height == last_page_height:
        break
    last_page_height = new_page_height

# %%
html_source = driver.page_source

# %%
soup = BeautifulSoup(html_source, 'lxml')

# %%
youtube_comments = soup.select('yt-formatted-string#content-text')

# %%
str_youtube_userIDs = []
str_youtube_comments = []
for i in range(len(youtube_user_IDs)):
    str_tmp = str(youtube_user_IDs[i].text)
    # print(str_tmp)
    str_tmp = str_tmp.replace('\n', '')
    str_tmp = str_tmp.replace('\t', '')
    str_tmp = str_tmp.replace(' ','')
    str_youtube_userIDs.append(str_tmp)
    str_tmp = str(youtube_comments[i].text)
    str_tmp = str_tmp.replace('\n', '')
    str_tmp = str_tmp.replace('\t', '')
    str_tmp = str_tmp.replace(' ', '')
    str_youtube_comments.append(str_tmp)

# %%
for i in range(len(str_youtube_userIDs)):
    print(str_youtube_userIDs[i], str_youtube_comments[i])
# Out:
# 김정환 (2:34:32)<-누르고리플레이버튼누르면광고없이쭉들을수있습니다!(0:01)H.O.T-캔디(3:37)코요태-만남(7:12)S.E.S-I'myourgirl(10:56)자자-버스안에서(14:11)쿨-애상(17:42)터보-TwistKing(21:46)코요태-순정(25:30)베이비복스-야야야(29:25)임창정-바람과함께사라지다(33:32)DJDOC-RunToYou(37:19)박진영-Honey(40:53)코요태-실연(44:14)클론-쿵따리샤바라(48:10)영턱스클럽-정(52:06)엄정화-Poison(55:54)핑클-내남자친구에게(59:54)터보-Goodbyeyesterday(1:03:41)김현정-그녀와의이별(1:07:45)S.E.S-너를사랑해(1:11:21)비비-하늘땅별땅(1:14:59)쿨-슬퍼지려하기전에(1:19:05)터보-LoveIs(1:23:00)코요태-비몽(1:26:22)이정현-줄래(1:30:06)H.O.T-행복(1:33:40)파파야-사랑만들기(1:37:35)지오디-관찰(1:41:13)홍경민-흔들린우정(1:45:08)젝스키스-커플(1:49:20)미나-전화받어(1:52:34)베이비복스-우연(1:56:34)솔리드-천생연분(2:00:23)하늘-웃기네(2:03:39)클론-초련(2:07:52)유피-뿌요뿌요(2:11:51)루머스-Storm(2:15:36)핑클-늘지금처럼(2:19:27)터보-애인이생겼어요(2:23:07)S.E.S-Oh,MyLove(2:26:42)언타이틀-날개(2:30:31)조성모-다짐
# 드르륵쾅 나만10대..인데들으러왔구나
# 박지환 00년대생중에서태어나기도전에노래좋아하는사람엄청많더라(상상그이상임)...이전세대는안이랬는데그만큼다들옛날감성을좋아하는듯
# 하늘 뭐야..나06년생인데90년대노래가좋은건뭐지..??
# 잼잼 저작권때문에광고가저절로붙여지는거아닌가그래서광고없애는법도알려주신거같은데무턱대고욕부터하진맙시다
# 점점 난16살인데요즘노래가90년대그노래따라갈수없는거같다ㅋㅋㅋㅋ요즘에는비트에집중을한다면90년대노래는가사에집중해서듣는맛도나고너무좋아ㅠㅠ
# ...

# %%
file = open('유튜브크롤링최종.txt', 'w')

# %%
import pandas as pd
file = {"ID":str_youtube_userIDs, "Comment":str_youtube_comments}
youtube_pd = pd.DataFrame(file)

# %%
youtube_pd.head(5)
# Out:
#      ID                                            Comment
# 0   김정환  (2:34:32)<-누르고리플레이버튼누르면광고없이쭉들을수있습니다!(0:01)H.O....
# 1  드르륵쾅                                    나만10대..인데들으러왔구나
# 2   박지환  00년대생중에서태어나기도전에노래좋아하는사람엄청많더라(상상그이상임)...이전세대는안이...
# 3    하늘                        뭐야..나06년생인데90년대노래가좋은건뭐지..??
# 4    잼잼  저작권때문에광고가저절로붙여지는거아닌가그래서광고없애는법도알려주신거같은데무턱대고욕부터하...

# %%
print("Running Time : ", time.time() - start)
# Out:
# Running Time :  2089.6636924743652

# %%
youtube_pd.to_excel("유튜브크롤링.xlsx", index=True)

# %% [markdown]
# ### 유튜브크롤링2

# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver as wd

## CHECK START TIME
start = time.time()       # 시작 시간 (전체 수행시간을 구하기 위함)
driver = wd.Chrome(executable_path="C:/BigData/projects/chromedriver/chromedriver.exe")

# INPUT YOUTUBE URL
url = "https://www.youtube.com/watch?v=6feWllD3csU"       # 댓글 수집할 Youtube URL입력
driver.get(url)

# %%
last_page_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(3.0)
    new_page_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    if new_page_height == last_page_height:
        break
    last_page_height = new_page_height

# %%
html_source = driver.page_source

# %%
soup = BeautifulSoup(html_source, 'lxml')

# %%
youtube_comments = soup.select('yt-formatted-string#content-text')

# %%
str_youtube_userIDs = []
str_youtube_comments = []
for i in range(len(youtube_user_IDs)):
    str_tmp = str(youtube_user_IDs[i].text)
    # print(str_tmp)
    str_tmp = str_tmp.replace('\n', '')
    str_tmp = str_tmp.replace('\t', '')
    str_tmp = str_tmp.replace(' ','')
    str_youtube_userIDs.append(str_tmp)
    str_tmp = str(youtube_comments[i].text)
    str_tmp = str_tmp.replace('\n', '')
    str_tmp = str_tmp.replace('\t', '')
    str_tmp = str_tmp.replace(' ', '')
    str_youtube_comments.append(str_tmp)

# %%
for i in range(len(str_youtube_userIDs)):
    print(str_youtube_userIDs[i], str_youtube_comments[i])
# Out:
# 24.델몬트광고/김C-구아바송(2004)(06:28)
# 드르륵쾅 폴더쓰던시절실수로가운데버튼잘못눌러서네이트들어가면호다닥나와야했음ㅠㅠ요금나가서엄마한테등짝스매싱맞으니까그시절스도쿠는지금쿠키런급게임이었고추억이다ㄹㅇ...
# 박지환 저때개콘끝나는음악들리면기분개우울해짐
# 하늘 어릴때비밀번호486부르다가"6번의키스를해줘~"이부분만나오면부끄러워서갑자기딴짓했던거생각난다..순수했다내어린시절...
# 잼잼 오렌지주스나물얼려서빨간지도손수건으로싸매서소풍갔던때생각난다ㅠㅠㅠㅠㅠㅠㅠ지리산손수건이였낰ㅋㅋㅋㅋㅋㅋ
# 점점 진짜예전뮤비는남여누구하나죽어야끝나는사랑ㅋㅋㅋㅋ
# 김기훈 이때감성제대로느끼려면엠피로들어야함
# GracePark 96라인손들어라놀토학교가는토요일수업일찍끝나고지옥탈출하고분식점가서떡볶이슬러시피카츄학교앞문방구에서메탈슬러그동물철권불량식품..
# 나집가게해줘 진짜응답하라시즌2002나왓으면93년생초딩들이주인공인ㅋㅋㅋㅋㅋ다기억나는데소재도많지않나?ㅠ
# 뻐엿 일요일저녁개콘보며마지막밴드노래나올때면아일욜이끝났구나낼학교가네ㅠㅠㅠ이럼서아쉬움과함께한주를마무리했는뎅...ex-안녕하세요아시는분....?
# 미현 옛날뮤비특1.한여자가지고남자둘이서패거리데리고맨날싸움2.도망치는씬무조건필수(코너돌면깡패등장)3.여자랑안좋은일나면화장실에서울면서거울주먹으로뿌수기(피나도병원안가고붕대로감아야됨,아님여자가손수건으로감아줌울면서)4.여자든남자든교통사고나서죽음5.여자웃고있으면남자가몰래쳐다봄여자랑눈마주치면남자건물뒤로숨고여자다시우울모드하뮤비보는맛이있었지옛날은단편드라마였면요즘은진짜예술적임
# 스와제 94년생여기
# jennieBaek 미니게임천국아는사람있나??
# 오렌지나비TV 예전에ㅋㅋㅋ초등학교때소풍갈때쿠우안챙겨가면섭섭했는데ㅋㅋㅋ
# LEGO조립도창고 벌써일년하면그썰밖에생각안나...어떤분이돌잔치에서벌써일년불러줬다고ㅋㅋㅋㅋㅋㅋㅋ
# 루민즈 97년생이라여기선명함도못내밀나이지만저도추억냄새가폴폴나네요
# DestinyLily 93년생모르는거없다
# ...

# %%
file = open('유튜브크롤링111.txt', 'w')

# %%
import pandas as pd
file = {"ID":str_youtube_userIDs, "Comment":str_youtube_comments}
youtube_pd = pd.DataFrame(file)

# %%
youtube_pd.head(5)
# Out:
#      ID                                            Comment
# 0   김정환  [Tracklist]\r1.버즈–가시(2005)(00:06)\r2.괴짜가족오프닝/전...
# 1  드르륵쾅  폴더쓰던시절실수로가운데버튼잘못눌러서네이트들어가면호다닥나와야했음ㅠㅠ요금나가서엄마한테등...
# 2   박지환                                저때개콘끝나는음악들리면기분개우울해짐
# 3    하늘  어릴때비밀번호486부르다가"6번의키스를해줘~"이부분만나오면부끄러워서갑자기딴짓했던거생...
# 4    잼잼  오렌지주스나물얼려서빨간지도손수건으로싸매서소풍갔던때생각난다ㅠㅠㅠㅠㅠㅠㅠ지리산손수건이였...

# %%
youtube_pd.to_excel("유튜브크롤링2.xlsx", index=True)

# %% [markdown]
# ## 인스타 크롤링 (7080)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re

# %%
def insta_searching(word):
    url = "https://www.instagram.com/explore/tags/" + word
    return url

from selenium import webdriver
driver = webdriver.Chrome("C:/BigData/projects/chromedriver/chromedriver.exe")
import time

# %%
driver.get('https://www.instargram.com')
time.sleep(5) #시간을 넉넉히 설정합니다.

# %%
email = 'bsh2014@naver.com'   ### 사용할 계정 정보 입력
input_id = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[0]
input_id.clear()
input_id.send_keys(email)

# %%
password = 'rkddkwl0901!' ### 비번 정보 수정
input_pw = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[1]
input_pw.clear()
input_pw.send_keys(password)
input_pw.submit()

# %%
time.sleep(3)
word = "7080" #검색할 해시태그. 띄어쓰기를 사용하면 안됩니다
url = insta_searching(word)
driver.get(url)
time.sleep(2)

# %%
first = driver.find_element_by_css_selector("div._9AhH0")
first.click()
time.sleep(3)

# %%
#본문 내용, 작성 일시, 위치 정보 및 해시태그(#) 추출
import re 
def get_content(driver):
    # 1. 현재 페이지의 HTML 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')    
    # 2. 본문 내용 가져오기
    try:  			#여러 태그중 첫번째([0]) 태그를 선택  
        content = soup.select('div.C4VMK > span')[0].text 
        			#첫 게시글 본문 내용이 <div class="C4VMK"> 임을 알 수 있다.
                                #태그명이 div, class명이 C4VMK인 태그 아래에 있는 span 태그를 모두 선택.
    except:
        content = ' ' 
    # 3. 본문 내용에서 해시태그 가져오기(정규표현식 활용)
    tags = re.findall(r'#[^\s#,\\]+', content) # content 변수의 본문 내용 중 #으로 시작하며, #뒤에 연속된 문자(공백이나 #, \ 기호가 아닌 경우)를 모두 찾아 tags 변수에 저장
    # 4. 작성 일자 가져오기
    try:
        date = soup.select('time._1o9PC.Nzb55')[0]['datetime'][:10] #앞에서부터 10자리 글자
    except:
        date = ''
    # 5. 좋아요 수 가져오기
    try:
        like = soup.select('div.Nm9Fw > button')[0].text[4:-1] 
    except:
        like = 0
    # 6. 위치 정보 가져오기
    try:
        place = soup.select('div.JF9hh')[0].text
    except:
        place = ''
    data = [content, date, like, place, tags]
    return data

# %%
# 7. 수집한 정보 저장하기
def move_next(driver):
    right = driver.find_element_by_css_selector('a._65Bje.coreSpriteRightPaginationArrow') 
    right.click()
    time.sleep(3)

# %%
results =[]

# %%
target = 1000 #크롤링할 게시물 수
for i in range(target):
    data = get_content(driver) #게시물 정보 가져오기
    results.append(data)
    move_next(driver)

# %%
print(results[:2])
# Out:
# [['강남역 랭맥총평: 강남역에서 가장 핫한 집한줄평: 랭맥에서 생맥 한잔 할랙?.거리두기가 1단계로 완화되면서 가고 싶은 집이 있는가? 아재들의 감성을 넘어 젊은이들의 트랜디함까지 사로 잡은 랭맥을 소개한다. 지금부터 리뷰를 시작하겠다..오픈한지 1년정도 되었는데 인기가 얼마나 많은지 주말에는 그 넓은 공간이 거의 만석이 된다. 몇 천만원이나 한다는 스피커에서 90-00 노래가 나오면 어느샌가 어깨춤을 추고 있는 자신을 발견한다..강남역에서 학원도 다녀보고 자취도 해봤지만 사실 강남역에는 은근 갈 곳이 없다. 특히 밥을 먹고 2차로 갈만한 집은 아직까지도 떠오르는 곳이 10곳이 안 된다. .하지만 이젠 없는 거 빼고 다 있는 랭맥에서 해결할 수 있다. 치킨, 피자, 멕시칸샐러드, 마른안주, 파스타, 떡볶이에 전까지 없는 게 없다. 옆 테이블은 모엣샹동을 마시고 있더라. 호프집에서 샴페인 파는 거 왜 이렇게 색다르지. 돔페리뇽도 있다. 진짜 FLEX인건가..그렇다고 맛이 없으면 추천하겠는가? 처음에 사실 맛보다는 분위기라는 말들이 있었는데, 최근 메뉴를 개편하면서 맛이 확실히 좋아졌다. 이 정도라면 2차, 3차, 4차로 완벽하다. 안주 고민할 필요도 없고 말이다..물론 맥주잔을 얼려서 더 시원하면서 비쥬얼이 좋은 건 덤이다. 을지로에 가지 않아도 을지로 만선호프 골목이 생각나는 곳이다..최근에 가장 인상 깊었던 건 피자이다. 크러스트가 페이스트리이고 치즈가 넘치는 피자가 고급스럽진 않았지만 정말 분위기에 딱 어울리는 맛이다..이제 밖에 앉아서 술마시기는 춥고, 감성주점은 가기 버겁다보니(못가는거 아니다..) 이런 곳이 마음 편하더라. 가끔 술취해서 사진 찍고 있는 아저씨가 보이면 나니까 인사해줘라.. 맥주 한 잔 사드릴지도?.', '2020-10-14', '511', '랭맥', []], ['Paint is so underrated❤ Koenigsegg Agera R #7080| Picture by: @cars_in_zurich| Owner: @nidalbe
# ...

# %%
import pandas as pd
results_df = pd.DataFrame(results)
results_df.to_excel('7080.xlsx', index=False)

# %% [markdown]
# ### 인스타 크롤링(뉴트로)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re

# %%
def insta_searching(word):
    url = "https://www.instagram.com/explore/tags/" + word
    return url

from selenium import webdriver
driver = webdriver.Chrome("C:/BigData/projects/chromedriver/chromedriver.exe")
import time

# %%
driver.get('https://www.instargram.com')
time.sleep(5) #시간을 넉넉히 설정합니다.

# %%
email = 'bsh2014@naver.com'   ### 사용할 계정 정보 입력
input_id = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[0]
input_id.clear()
input_id.send_keys(email)

# %%
password = 'rkddkwl0901!' ### 비번 정보 수정
input_pw = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[1]
input_pw.clear()
input_pw.send_keys(password)
input_pw.submit()

# %%
time.sleep(3)
word = "뉴트로" #검색할 해시태그. 띄어쓰기를 사용하면 안됩니다
url = insta_searching(word)
driver.get(url)
time.sleep(2)

# %%
first = driver.find_element_by_css_selector("div._9AhH0")
first.click()
time.sleep(3)

# %%
#본문 내용, 작성 일시, 위치 정보 및 해시태그(#) 추출
import re 
def get_content(driver):
    # 1. 현재 페이지의 HTML 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')    
    # 2. 본문 내용 가져오기
    try:  			#여러 태그중 첫번째([0]) 태그를 선택  
        content = soup.select('div.C4VMK > span')[0].text 
        			#첫 게시글 본문 내용이 <div class="C4VMK"> 임을 알 수 있다.
                                #태그명이 div, class명이 C4VMK인 태그 아래에 있는 span 태그를 모두 선택.
    except:
        content = ' ' 
    # 3. 본문 내용에서 해시태그 가져오기(정규표현식 활용)
    tags = re.findall(r'#[^\s#,\\]+', content) # content 변수의 본문 내용 중 #으로 시작하며, #뒤에 연속된 문자(공백이나 #, \ 기호가 아닌 경우)를 모두 찾아 tags 변수에 저장
    # 4. 작성 일자 가져오기
    try:
        date = soup.select('time._1o9PC.Nzb55')[0]['datetime'][:10] #앞에서부터 10자리 글자
    except:
        date = ''
    # 5. 좋아요 수 가져오기
    try:
        like = soup.select('div.Nm9Fw > button')[0].text[4:-1] 
    except:
        like = 0
    # 6. 위치 정보 가져오기
    try:
        place = soup.select('div.JF9hh')[0].text
    except:
        place = ''
    # 아이디 정보 가져오기
    try:
        ID = soup.select('a.sqdOP.yWX7d._8A5w5.ZIAjV ')[0].text
    except:
        ID = ''
    data = [content, date, like, place, tags, ID]
    return data

# %%
# 7. 수집한 정보 저장하기
def move_next(driver):
    right = driver.find_element_by_css_selector('a._65Bje.coreSpriteRightPaginationArrow') 
    right.click()
    time.sleep(3)

# %%
results =[]

# %%
target = 1000 #크롤링할 게시물 수
for i in range(target):
    data = get_content(driver) #게시물 정보 가져오기
    results.append(data)
    move_next(driver)

# %%
import pandas as pd
results_df = pd.DataFrame(results)
results_df.to_excel('뉴트로.xlsx', index=False)

# %% [markdown]
# ### 네이버 블로그 크롤링

# %%
pip install tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from selenium import webdriver
import time
import tqdm
from tqdm.notebook import tqdm

# %%
query_txt = input('1.크롤링할 키워드는 무엇입니까?: ')
start_data = input('2.조회를 시작할 날짜를 입력하세요(예:2019-01-01) :')
end_data = input('3.조회를 종료할 날짜를 입력하세요(예:2019-12-31) :')
# Out:
# 1.크롤링할 키워드는 무엇입니까?: 셀토스 스테이션
# 2.조회를 시작할 날짜를 입력하세요(예:2019-01-01) :2019-01-01
# 3.조회를 종료할 날짜를 입력하세요(예:2019-12-31) :2020-10-22

# %%
path = "chromedriver.exe"
driver = webdriver.Chrome("C:/BigData/projects/chromedriver/chromedriver.exe")
driver.get('http://www.naver.com')
time.sleep(2)

#네이버 검색창에 "검색어"검색
element = driver.find_element_by_id("query")
element.send_keys(query_txt)
element.submit()

#"블로그" 카테고리 선택
driver.find_element_by_link_text("블로그").click()

# %%
#오른쪽의 검색 옵션 버튼 클릭
driver.find_element_by_id("_search_option_btn").click()

#정렬 : 관련도순
driver.find_element_by_xpath("""//*[@id="snb"]/div/ul/li[1]/a""").click() #정렬 버튼의 xpath 클로
driver.find_element_by_xpath("""//*[@id="snb"]/div/ul/li[1]/div/ul/li[1]/a""").click() #관련도순

# %%
#날짜 입력
driver.find_element_by_xpath("""//*[@id="snb"]/div/ul/li[2]/a""").click()
time.sleep(2)

#시작 날짜 입력하기
s_date = driver.find_element_by_xpath("""//*[@id="blog_input_period_begin"]""")
driver.find_element_by_xpath("""//*[@id="blog_input_period_begin"]""").click()
s_date.clear()
time.sleep(1)

#날짜를 반복문으로 1글자씩 입력
for c in start_data:
    s_date.send_keys(c)
    time.sleep(0.1)
    
#종료 날짜 입력
e_date = driver.find_element_by_xpath("""//*[@id="blog_input_period_end"]""")
driver.find_element_by_xpath("""//*[@id="blog_input_period_end"]""").click()
e_date.clear()
time.sleep(1)

for c in end_data:
    e_date.send_keys(c)
    time.sleep(0.1)
    
#날짜입력 "적용하기"버튼 클릭
driver.find_element_by_class_name("tx").click()
time.sleep(3)

# %%
url_list = []
title_list = []

#몇개 페이지를 크롤링 할지
total_page = 10
for i in tqdm(range(0, total_page)):
    i = i*10 + 1
    url = "https://search.naver.com/search.naver?where=post&query=%EC%85%80%ED%86%A0%EC%8A%A4%20%EC%8A%A4%ED%85%8C%EC%9D%B4%EC%85%98&st=sim&sm=tab_opt&date_from=&date_to=&date_option=0&srchby=all&dup_remove=1&post_blogurl=&post_blogurl_without=&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall"\
    .format(i)
    
    driver.get(url)
    time.sleep(0.5)
    
    # URL 크롤링 시작
    titles = "a.sh_blog_title._sp_each_url._sp_each_title"
    article_raw = driver.find_elements_by_css_selector(titles)
    
    for article in article_raw:
        url = article.get_attribute('href')
        url_list.append(url)
        
    # 제목 크롤링 시작
    for article in article_raw:
        title = article.get_attribute('title')
        title_list.append(title)
        
        print(title)
# Out:
# ...
# [Travel] 기아 셀토스 팝업 스토어 '셀토스 스테이션' 방문
# [방문기] 서울시 신사동 "셀토스 스테이션" 방문기-(2) '2nd Floor'
# 기아 셀토스 스테이션 팝업스토어 오픈
# 기아차, 가로수길에 ‘셀토스 스테이션’ 팝업스토어 오픈
# KIA 셀토스 >> 휴볼트 radi8t12 다크미스트 19인치휠+한국타이어 저소음 프리미엄 벤투스V V2 AS 타이어 장착! -티스테이션 월곶점-
# 여수휠 전문샾 티스테이션 기아셀토스18인치 임판급휠로 교체순정16인치에서
# 익산부송점 익산오토스테이션 셀토스 i55 35%, 5%
# 기아 셀토스 in 신사동 [자동차 블로그]
# 기아자동차 셀토스 스테이션
# 소형 SUV 돌풍 셀토스 최근 소식 전해드립니다.
# [Travel] 기아 셀토스 팝업 스토어 '셀토스 스테이션' 방문
# [방문기] 서울시 신사동 "셀토스 스테이션" 방문기-(2) '2nd Floor'
# 기아 셀토스 스테이션 팝업스토어 오픈
# 기아차, 가로수길에 ‘셀토스 스테이션’ 팝업스토어 오픈
# KIA 셀토스 >> 휴볼트 radi8t12 다크미스트 19인치휠+한국타이어 저소음 프리미엄 벤투스V V2 AS 타이어 장착! -티스테이션 월곶점-
# 여수휠 전문샾 티스테이션 기아셀토스18인치 임판급휠로 교체순정16인치에서
# 익산부송점 익산오토스테이션 셀토스 i55 35%, 5%
# 기아 셀토스 in 신사동 [자동차 블로그]
# 기아자동차 셀토스 스테이션
# 소형 SUV 돌풍 셀토스 최근 소식 전해드립니다.
# [Travel] 기아 셀토스 팝업 스토어 '셀토스 스테이션' 방문
# [방문기] 서울시 신사동 "셀토스 스테이션" 방문기-(2) '2nd Floor'
# 기아 셀토스 스테이션 팝업스토어 오픈
# 기아차, 가로수길에 ‘셀토스 스테이션’ 팝업스토어 오픈
# KIA 셀토스 >> 휴볼트 radi8t12 다크미스트 19인치휠+한국타이어 저소음 프리미엄 벤투스V V2 AS 타이어 장착! -티스테이션 월곶점-
# ...

# %%
df = pd.DataFrame({'url':url_list, 'title':title_list})

#저장하기
df.to_excel("셀토스스테이션.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1d87629a49b2> in <module>
# ----> 1 df = pd.DataFrame({'url':url_list, 'title':title_list})
#       2
#       3 #저장하기
#       4 df.to_excel("셀토스스테이션.xlsx")
#
# NameError: name 'url_list' is not defined

# %%
#url_list 불러오기
url_load = pd.read_excel("blog_url.xlsx")

num_list = len(url_load)

print(num_list)
url_load
# Out:
# 1000
#      Unnamed: 0                                                url  \
# 0             0  https://blog.naver.com/suyounghd?Redirect=Log&...
# 1             1  https://blog.naver.com/hisblue35?Redirect=Log&...
# 2             2  https://blog.naver.com/1003hdh?Redirect=Log&lo...
# 3             3  https://blog.naver.com/ulkeuni96?Redirect=Log&...
# 4             4  https://blog.naver.com/foodbeen?Redirect=Log&l...
# ..          ...                                                ...
# 995         995  https://blog.naver.com/ghqkd0829?Redirect=Log&...
# 996         996  https://blog.naver.com/krahn82?Redirect=Log&lo...
# 997         997  https://blog.naver.com/twilight0723?Redirect=L...
# 998         998  https://blog.naver.com/omaha97?Redirect=Log&lo...
# 999         999  https://blog.naver.com/yisoyeong?Redirect=Log&...
#
#                                                  title
# 0                                    테라조타일 뉴트로 감성의 포인트
# ...

# %%
dict = {}
number = 1000
for i in tqdm(range(0,number)):
    
    url= url_load['url'][i]
    driver = webdriver.Chrome(path)
    driver.get(url)

    try:
        driver.switch_to_frame('mainFrame')
        target_info = {}
        # print(1)
        overlays=".se-fs-.se-ff-"
        # print(34)
        tit = driver.find_element_by_css_selector(overlays) # title
        #print(tit)
        title = tit.text
        title
        #print(title)

        # 글쓴이 크롤링 시작
        overlays = ".nick"
        nick = driver.find_element_by_css_selector(overlays)
        # print(nick)
        nickname = nick.text
        
        overlays = ".se_publishDate.pcol2"
        date = driver.find_element_by_css_selector(overlays)
        datetime = date.text
        
        # print(nickname)
        # 내용 크롤링
        overlays = '.se-component.se-text.se-l-default'
        contents = driver.find_elements_by_css_selector(overlays)
        content_list = []
        
        for content in contents:
            content_list.append(content.text)
        
        # print(2)
        # print(content)
        content_str = ' '.join(content_list)

        # 글 하나는 target_info라는 딕셔너리에 담기게 되고,
        target_info['title'] = title
        target_info['nickname'] = nickname
        target_info['content'] = content_str
        target_info['datetime'] = datetime
        
        print(3)
        # 각각의 글은 dict라는 딕셔너리에 담기게 됩니다.
        dict[i] = target_info
        time.sleep(1)

        #print(i, title)

        # 글 하나 크롤링 후 크롬 창 닫기
        driver.close()
        # 에러나면 현재 크롬창 닫고 다음 글(i+1)로 이동
    except:
        driver.close()
        time.sleep(1)
        continue

    if i==30 or 50 or 80:
        result_df = pd.DataFrame.from_dict(dict, 'index')

        result_df.to_excel('blog_content.xlsx')
        time.sleep(3)
print(len(dict))
# Out:
# ...
# C:\BigData\anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: use driver.switch_to.frame instead
#   # Remove the CWD from sys.path while we load stuff.
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ...

# %% [markdown]
# ### 블로그 크롤링 - 기아팝업스토어

# %%
import sys
import os
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from selenium import webdriver
import time
import tqdm
from tqdm.notebook import tqdm

# %%
query_txt = input('1.크롤링할 키워드는 무엇입니까?: ')
start_date = input('2.조회를 시작할 날짜를 입력하세요(예:2019-01-01) :')
end_date = input('3.조회를 종료할 날짜를 입력하세요(예:2019-12-31) :')
# Out:
# 1.크롤링할 키워드는 무엇입니까?: 기아 팝업스토어
# 2.조회를 시작할 날짜를 입력하세요(예:2019-01-01) :2017-01-01
# 3.조회를 종료할 날짜를 입력하세요(예:2019-12-31) :2019-12-31

# %%
path = "chromedriver.exe"
driver = webdriver.Chrome("C:/BigData/projects/chromedriver/chromedriver.exe")
driver.get('http://www.naver.com')
time.sleep(2)

#네이버 검색창에 "검색어"검색
element = driver.find_element_by_id("query")
element.send_keys(query_txt)
element.submit()

#"블로그" 카테고리 선택
driver.find_element_by_link_text("블로그").click()

# %%
#오른쪽의 검색 옵션 버튼 클릭
driver.find_element_by_id("_search_option_btn").click()

#정렬 : 관련도순
driver.find_element_by_xpath("""//*[@id="snb"]/div/ul/li[1]/a""").click() #정렬 버튼의 xpath 클로
driver.find_element_by_xpath("""//*[@id="snb"]/div/ul/li[1]/div/ul/li[1]/a""").click() #관련도순

# %%
#날짜 입력
driver.find_element_by_xpath("""//*[@id="snb"]/div/ul/li[2]/a""").click()
time.sleep(2)

#시작 날짜 입력하기
s_date = driver.find_element_by_xpath("""//*[@id="blog_input_period_begin"]""")
driver.find_element_by_xpath("""//*[@id="blog_input_period_begin"]""").click()
s_date.clear()
time.sleep(1)

#날짜를 반복문으로 1글자씩 입력
for c in start_date:
    s_date.send_keys(c)
    time.sleep(0.1)
    
#종료 날짜 입력
e_date = driver.find_element_by_xpath("""//*[@id="blog_input_period_end"]""")
driver.find_element_by_xpath("""//*[@id="blog_input_period_end"]""").click()
e_date.clear()
time.sleep(1)

for c in end_date:
    e_date.send_keys(c)
    time.sleep(0.1)
    
#날짜입력 "적용하기"버튼 클릭
driver.find_element_by_class_name("tx").click()
time.sleep(3)

# %%
url_list = []
title_list = []

#몇개 페이지를 크롤링 할지
total_page = 10
for i in tqdm(range(0, total_page)):
    i = i*10 + 1
    url = "https://search.naver.com/search.naver?date_from=20170101&date_option=8&date_to=20191231&dup_remove=1&nso=p%3Afrom20170101to20191231&post_blogurl=&post_blogurl_without=&query=%EA%B8%B0%EC%95%84%20%ED%8C%9D%EC%97%85%EC%8A%A4%ED%86%A0%EC%96%B4&sm=tab_pge&srchby=all&st=sim&where=post&start=" + str(i)\
    .format(start_date,end_date,start_date,end_date,query_txt, i)
      
    driver.get(url)
    time.sleep(0.5)

# def bolg_craling(page=1):
#     url = "https://search.naver.com/search.naver?where=post&query=%EC%85%80%ED%86%A0%EC%8A%A4%20%EC%8A%A4%ED%85%8C%EC%9D%B4%EC%85%98&st=sim&sm=tab_opt&date_from=20190101&date_to=20201022&date_option=8&srchby=all&dup_remove=1&post_blogurl=&post_blogurl_without=&nso=so%3Ar%2Ca%3Aall%2Cp%3Afrom20190101to20201022"\
#     .format(page)
#     blog_post_list = []
#     for i in range(1,100,10):
#         blog_post_list.extend(blog_crawling(page=1))
#         time.sleep(2)
# save_data(blog_post_list)
        
    # URL 크롤링 시작
    titles = "a.sh_blog_title._sp_each_url._sp_each_title"
    article_raw = driver.find_elements_by_css_selector(titles)
    
    for article in article_raw:
        url = article.get_attribute('href')
        url_list.append(url)
        
    # 제목 크롤링 시작
    for article in article_raw:
        title = article.get_attribute('title')
        title_list.append(title)

        print(title)
# Out:
# ...
# 기아 셀토스 팝업스토어 주말 가볼만한 가로수길 놀거리 어때?
# [Travel] 기아 셀토스 팝업 스토어 '셀토스 스테이션' 방문
# 기아자동차, 셀토스 팝업 스토어 가로수길에 오픈
# 기아 셀토스 스테이션 팝업스토어 오픈
# 기아차, 가로수길에 ‘셀토스 스테이션’ 팝업스토어 오픈
# 셀토스 팝업스토어
# 메르세데스 벤츠의 첫 순수전기차 EQC 런칭 행사, 가로수길 EQ Future 팝업스토어에서 만나 본 미래 모빌리티
# 기아차, 프리미엄 팝업 스토어 ‘스팅어 스테이션’ 운영
# [기아] 프리미엄 팝업 스토어 ‘스팅어 스테이션’ 운영
# 기아차, 스팅어 팝업 스토어 '스팅어 스테이션' 운영
# 기아차, 프리미엄 팝업 스토어 ‘스팅어 스테이션’ 운영
# 기아차, 프리미엄 팝업 스토어 ‘스팅어 스테이션’ 운영
# 홍대 기아자동차 모닝 팝업스토어 스마트펀스토어
# 압구정동 팝업스토어
# [POPUP STORE] 소녀시대 서현과 함께하는 바이서우 팝업스토어!
# [현대백화점 중동점] 시로앤마로 팝업스토어 다녀왔어요❤️
# 기아차, 프리미엄 팝업 스토어 ‘스팅어 스테이션’ 운영…전시·시승 체험
# [poled] IFC몰 폴레드 카시트 팝업스토어 현장 스케치
# #가로수길데이트 #가로수길탬버린즈 #셀토스팝업스토어 #가로수길펍 : TRETAIR Bar & Coffee 트리타
# 부산 롯데백화점 광복점 시로앤마로 시바 팝업스토어
# 하루 20만명 유동인구 서울 최고의 팝업스토어 광장 안내
# [테이너.컨테이너.조립 테이너.부스 테이너.이벤트 부스.행사 부스.팝업스토어]홍대 현대 기아 자동차
# 시트로엥, 스타필드 하남 팝업스토어 운영
# 프리미엄 팝업 스토어 스팅어 스테이션(Stinger Station) 운영
# 기아자동차, '셀토스 스테이션' 가로수길에 팝업스토어 오픈
# 랜드로버 올 뉴 디스커버리 @코엑스 팝업스토어, 오프로드의 제왕 돌아와...
# 기아차, 홍대서 ‘모닝 스마트 펀 스토어’ 운영
# ...

# %%
df = pd.DataFrame({'url':url_list, 'title':title_list})

#저장하기
df.to_excel("기아팝업스토어.xlsx")

# %%
#url_list 불러오기
url_load = pd.read_excel("기아팝업스토어.xlsx")

num_list = len(url_load)

print(num_list)
url_load
# Out:
# 100
#     Unnamed: 0                                                url  \
# 0            0              https://crysta06.blog.me/221618009379
# 1            1  https://blog.naver.com/kyungms03?Redirect=Log&...
# 2            2  https://blog.naver.com/p47jhy5uhy?Redirect=Log...
# 3            3  https://blog.naver.com/tkxkdcpfl2?Redirect=Log...
# 4            4  https://blog.naver.com/allenhan?Redirect=Log&l...
# ..         ...                                                ...
# 95          95             http://blog.daum.net/eventnet/15947803
# 96          96  https://blog.naver.com/esuccess?Redirect=Log&l...
# 97          97  https://blog.naver.com/fcblog?Redirect=Log&log...
# 98          98                   https://www.leaderyou.co.kr/6022
# 99          99               https://tearsjs.blog.me/221471510067
#
#                                                 title
# 0                   기아 셀토스 팝업스토어 주말 가볼만한 가로수길 놀거리 어때?
# 1                [Travel] 기아 셀토스 팝업 스토어 '셀토스 스테이션' 방문
# ...

# %%
dict = {}
number = 100
for i in tqdm(range(0,number)):
    
    url= url_load['url'][i]
    driver = webdriver.Chrome(path)
    driver.get(url)

    try:
        driver.switch_to_frame('mainFrame')
        target_info = {}
        # print(1)
        overlays=".se-fs-.se-ff-"
        # print(34)
        tit = driver.find_element_by_css_selector(overlays) # title
        #print(tit)
        title = tit.text
        title
        #print(title)

        # 글쓴이 크롤링 시작
        overlays = ".nick"
        nick = driver.find_element_by_css_selector(overlays)
        # print(nick)
        nickname = nick.text
        
        overlays = ".se_publishDate.pcol2"
        date = driver.find_element_by_css_selector(overlays)
        datetime = date.text
        
        # print(nickname)
        # 내용 크롤링
        overlays = '.se-component.se-text.se-l-default'
        contents = driver.find_elements_by_css_selector(overlays)
        content_list = []
        
        for content in contents:
            content_list.append(content.text)
        
        # print(2)
        # print(content)
        content_str = ' '.join(content_list)

        # 글 하나는 target_info라는 딕셔너리에 담기게 되고,
        target_info['title'] = title
        target_info['nickname'] = nickname
        target_info['content'] = content_str
        target_info['datetime'] = datetime
        
        print(3)
        # 각각의 글은 dict라는 딕셔너리에 담기게 됩니다.
        dict[i] = target_info
        time.sleep(1)

        #print(i, title)

        # 글 하나 크롤링 후 크롬 창 닫기
        driver.close()
        # 에러나면 현재 크롬창 닫고 다음 글(i+1)로 이동
    except:
        driver.close()
        time.sleep(1)
        continue

    if i==30 or 50 or 80:
        result_df = pd.DataFrame.from_dict(dict, 'index')

        result_df.to_excel('기아팝업스토어_내용.xlsx')
        time.sleep(3)
print(len(dict))
# Out:
# ...
# C:\BigData\anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: use driver.switch_to.frame instead
#   # Remove the CWD from sys.path while we load stuff.
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-71-c215be329b01> in <module>
#       4
#       5     url= url_load['url'][i]
# ----> 6     driver = webdriver.Chrome(path)
#       7     driver.get(url)
#       8
#
# C:\BigData\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ...

# %% [markdown]
# ### 파이차트

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rc
from matplotlib import style

# %%
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
style.use('ggplot')

# %%
labels = ['기프티쇼', '카카오', '소셜커머스', '기타']
ratio = [488556, 1332090, 1857590, 1304261]

# %%
plt.pie(ratio, labels=labels, shadow=True, startangle=90)
plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [488556, 1332090, 1857590, 1304261]
labels = ['기프티쇼', '카카오', '소셜커머스', '기타']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()
